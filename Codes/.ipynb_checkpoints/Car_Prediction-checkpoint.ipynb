# %%
# import our modules 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import os
import seaborn as sns

# %%
Car_file_path = os.path.join(os.path.pardir,'Datasets','Car.xls')

Car_df =pd.read_excel(Car_file_path)

# %%
Car_df
# Out:
#        Manufacturer                                       Model  \
# 0        ALFA ROMEO       MiTo Series 3, September 2016 Onwards
# 1               BMW    1 Series 3-door F21, From September 2012
# 2               BMW    1 Series 5-door F20, From September 2011
# 3           CITROEN                                          C4
# 4           CITROEN                                   C4 Cactus
# 5             DACIA                       Logan MCV Euro6, 2015
# 6             DACIA                          Sandero Euro6 2015
# 7                DS                                         DS3
# 8              FIAT          500 & 500C, September 2015 onwards
# 9              FIAT      Tipo Hatchback, September 2016 Onwards
# 10             FIAT  Tipo Station Wagon, September 2016 Onwards
# 11             FORD       All New Fiesta, Model Year Post 2017æ
# 12             FORD       All New Fiesta, Model Year Post 2017æ
# 13             FORD       All New Fiesta, Model Year Post 2017æ
# ...

# %%
#drop the null columns
Car_df.drop(['Electric energy consumption Miles/kWh','wh/km','Maximum range (Km)','Maximum range (Miles)'],axis=1,inplace=True)

# %%
Car_df.head()
# Out:
#   Manufacturer                                     Model  \
# 0   ALFA ROMEO     MiTo Series 3, September 2016 Onwards
# 1          BMW  1 Series 3-door F21, From September 2012
# 2          BMW  1 Series 5-door F20, From September 2011
# 3      CITROEN                                        C4
# 4      CITROEN                                 C4 Cactus
#
#                Description Transmission  Engine Capacity Fuel Type  \
# 0        1.3 JTDm-2 95 bhp           M5           1248.0    Diesel
# 1  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 2  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 3          BlueHDi 100 S&S           M5           1560.0    Diesel
# 4     BlueHDi 100 S&S ETG6         AMT6           1560.0    Diesel
#
#    Metric Urban (Cold)  Metric Extra-Urban  Metric Combined  \
# 0                  4.3                 2.9              3.4
# 1                  3.9                 3.1              3.4
# ...

# %%
Car_df.drop(['Electricity cost'],axis=1,inplace=True)

# %%
Car_df.head()
# Out:
#   Manufacturer                                     Model  \
# 0   ALFA ROMEO     MiTo Series 3, September 2016 Onwards
# 1          BMW  1 Series 3-door F21, From September 2012
# 2          BMW  1 Series 5-door F20, From September 2011
# 3      CITROEN                                        C4
# 4      CITROEN                                 C4 Cactus
#
#                Description Transmission  Engine Capacity Fuel Type  \
# 0        1.3 JTDm-2 95 bhp           M5           1248.0    Diesel
# 1  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 2  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 3          BlueHDi 100 S&S           M5           1560.0    Diesel
# 4     BlueHDi 100 S&S ETG6         AMT6           1560.0    Diesel
#
#    Metric Urban (Cold)  Metric Extra-Urban  Metric Combined  \
# 0                  4.3                 2.9              3.4
# 1                  3.9                 3.1              3.4
# ...

# %% [markdown]
# ### determine the target and the feature

# %%
#Total cost is the target or is the predicted variable
# but total cost and fuel cost columns are the same so we can drop one of them

# %%
Car_df.drop('Fuel Cost 12000 Miles',axis=1,inplace=True)

# %%
Car_df.head()
# Out:
#   Manufacturer                                     Model  \
# 0   ALFA ROMEO     MiTo Series 3, September 2016 Onwards
# 1          BMW  1 Series 3-door F21, From September 2012
# 2          BMW  1 Series 5-door F20, From September 2011
# 3      CITROEN                                        C4
# 4      CITROEN                                 C4 Cactus
#
#                Description Transmission  Engine Capacity Fuel Type  \
# 0        1.3 JTDm-2 95 bhp           M5           1248.0    Diesel
# 1  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 2  116d ED Plus 16'' tyres           M6           1496.0    Diesel
# 3          BlueHDi 100 S&S           M5           1560.0    Diesel
# 4     BlueHDi 100 S&S ETG6         AMT6           1560.0    Diesel
#
#    Metric Urban (Cold)  Metric Extra-Urban  Metric Combined  \
# 0                  4.3                 2.9              3.4
# 1                  3.9                 3.1              3.4
# ...

# %%
#Second the features can be more than one to have a good model
#Engine Capacity,Fuel Type,Transmission,Emissions

# %% [markdown]
# ### Data preprocessing

# %%
Car_df.isna().sum()
# Out:
# Manufacturer                      0
# Model                             0
# Description                       0
# Transmission                     32
# Engine Capacity                  30
# Fuel Type                         0
# Metric Urban (Cold)              81
# Metric Extra-Urban               81
# Metric Combined                  30
# Imperial Urban (Cold)            81
# Imperial Extra-Urban             81
# Imperial Combined                30
# CO2 g/km                          0
# Total cost / 12000 miles          0
# Euro Standard                     0
# Noise Level dB(A)                 0
# Emissions CO [mg/km]             30
# THC Emissions [mg/km]          2611
# Emissions NOx [mg/km]            30
# THC + NOx Emissions [mg/km]    2536
# Particulates [No.] [mg/km]     2529
# dtype: int64

# %%
#as we see that the 3 columns which are :THC + NOx Emissions,Particulates [No.],THC Emissions 
#have approximately half of thier values are null so replace by mean()

# %%
# import the modules we need
from sklearn.preprocessing import Imputer
# make a new imputer 
imputer = Imputer(missing_values='NaN', strategy='mean',axis=0)
Car_df[['THC Emissions [mg/km]', 'THC + NOx Emissions [mg/km]','Particulates [No.] [mg/km]']] = imputer.fit_transform(Car_df[['THC Emissions [mg/km]', 'THC + NOx Emissions [mg/km]','Particulates [No.] [mg/km]']])
Car_df
# Out:
# /Users/maialaa/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
#        Manufacturer                                       Model  \
# 0        ALFA ROMEO       MiTo Series 3, September 2016 Onwards
# 1               BMW    1 Series 3-door F21, From September 2012
# 2               BMW    1 Series 5-door F20, From September 2011
# 3           CITROEN                                          C4
# 4           CITROEN                                   C4 Cactus
# 5             DACIA                       Logan MCV Euro6, 2015
# 6             DACIA                          Sandero Euro6 2015
# 7                DS                                         DS3
# 8              FIAT          500 & 500C, September 2015 onwards
# ...

# %%
Car_df.isna().sum()
# Out:
# Manufacturer                    0
# Model                           0
# Description                     0
# Transmission                   32
# Engine Capacity                30
# Fuel Type                       0
# Metric Urban (Cold)            81
# Metric Extra-Urban             81
# Metric Combined                30
# Imperial Urban (Cold)          81
# Imperial Extra-Urban           81
# Imperial Combined              30
# CO2 g/km                        0
# Total cost / 12000 miles        0
# Euro Standard                   0
# Noise Level dB(A)               0
# Emissions CO [mg/km]           30
# THC Emissions [mg/km]           0
# Emissions NOx [mg/km]          30
# THC + NOx Emissions [mg/km]     0
# Particulates [No.] [mg/km]      0
# dtype: int64

# %%
#THE Other null values in the columns can be dropped as the are not much compared with the records raws

# %%
Car_df.dropna(subset=['Metric Urban (Cold)','Metric Extra-Urban','Imperial Urban (Cold)','Metric Combined','Imperial Combined','Imperial Extra-Urban','Transmission','Engine Capacity','Emissions CO [mg/km]','Emissions NOx [mg/km]'], inplace=True)

# %%
Car_df.isna().sum()
# Out:
# Manufacturer                   0
# Model                          0
# Description                    0
# Transmission                   0
# Engine Capacity                0
# Fuel Type                      0
# Metric Urban (Cold)            0
# Metric Extra-Urban             0
# Metric Combined                0
# Imperial Urban (Cold)          0
# Imperial Extra-Urban           0
# Imperial Combined              0
# CO2 g/km                       0
# Total cost / 12000 miles       0
# Euro Standard                  0
# Noise Level dB(A)              0
# Emissions CO [mg/km]           0
# THC Emissions [mg/km]          0
# Emissions NOx [mg/km]          0
# THC + NOx Emissions [mg/km]    0
# Particulates [No.] [mg/km]     0
# dtype: int64

# %% [markdown]
# ### Now there are no null values in the dataset !

# %% [markdown]
# ### Now we can convert categorial values to numeric ones using labelencoder

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
Car_df['Transmission'] = encoder.fit_transform(Car_df['Transmission'].astype(str))
Car_df
# Out:
#        Manufacturer                                       Model  \
# 0        ALFA ROMEO       MiTo Series 3, September 2016 Onwards
# 1               BMW    1 Series 3-door F21, From September 2012
# 2               BMW    1 Series 5-door F20, From September 2011
# 3           CITROEN                                          C4
# 4           CITROEN                                   C4 Cactus
# 5             DACIA                       Logan MCV Euro6, 2015
# 6             DACIA                          Sandero Euro6 2015
# 7                DS                                         DS3
# 8              FIAT          500 & 500C, September 2015 onwards
# 9              FIAT      Tipo Hatchback, September 2016 Onwards
# 10             FIAT  Tipo Station Wagon, September 2016 Onwards
# 11             FORD       All New Fiesta, Model Year Post 2017æ
# 12             FORD       All New Fiesta, Model Year Post 2017æ
# 13             FORD       All New Fiesta, Model Year Post 2017æ
# ...

# %%
Car_df
# Out:
#        Manufacturer                                       Model  \
# 0        ALFA ROMEO       MiTo Series 3, September 2016 Onwards
# 1               BMW    1 Series 3-door F21, From September 2012
# 2               BMW    1 Series 5-door F20, From September 2011
# 3           CITROEN                                          C4
# 4           CITROEN                                   C4 Cactus
# 5             DACIA                       Logan MCV Euro6, 2015
# 6             DACIA                          Sandero Euro6 2015
# 7                DS                                         DS3
# 8              FIAT          500 & 500C, September 2015 onwards
# 9              FIAT      Tipo Hatchback, September 2016 Onwards
# 10             FIAT  Tipo Station Wagon, September 2016 Onwards
# 11             FORD       All New Fiesta, Model Year Post 2017æ
# 12             FORD       All New Fiesta, Model Year Post 2017æ
# 13             FORD       All New Fiesta, Model Year Post 2017æ
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
Car_df['Model'] = encoder.fit_transform(Car_df['Model'].astype(str))
Car_df
# Out:
#        Manufacturer  Model                                        Description  \
# 0        ALFA ROMEO    330                                  1.3 JTDm-2 95 bhp
# 1               BMW      1                            116d ED Plus 16'' tyres
# 2               BMW      3                            116d ED Plus 16'' tyres
# 3           CITROEN    140                                    BlueHDi 100 S&S
# 4           CITROEN    141                               BlueHDi 100 S&S ETG6
# 5             DACIA    313                                             dCi 90
# 6             DACIA    419                                             dCi 90
# 7                DS    193                                    BlueHDi 100 S&S
# 8              FIAT     39                                1.3 MultiJet 95 bhp
# 9              FIAT    437                   1.6 MultiJet 120 bhp Elite (Eco)
# 10             FIAT    438                    1.6 MuliJet 120 bhp Elite (Eco)
# ...

# %%
Car_df['Description'] = encoder.fit_transform(Car_df['Description'].astype(str))
Car_df
# Out:
#        Manufacturer  Model  Description  Transmission  Engine Capacity  \
# 0        ALFA ROMEO    330          342            28           1248.0
# 1               BMW      1          902            30           1496.0
# 2               BMW      3          902            30           1496.0
# 3           CITROEN    140         2048            28           1560.0
# 4           CITROEN    141         2053            19           1560.0
# 5             DACIA    313         2951            28           1461.0
# 6             DACIA    419         2951            28           1461.0
# 7                DS    193         2048            28           1560.0
# 8              FIAT     39          343            28           1248.0
# 9              FIAT    437          750            30           1598.0
# 10             FIAT    438          747            30           1598.0
# 11             FORD     97          632            30           1499.0
# ...

# %%
Car_df.head()
# Out:
#   Manufacturer  Model  Description  Transmission  Engine Capacity Fuel Type  \
# 0   ALFA ROMEO    330          342            28           1248.0    Diesel
# 1          BMW      1          902            30           1496.0    Diesel
# 2          BMW      3          902            30           1496.0    Diesel
# 3      CITROEN    140         2048            28           1560.0    Diesel
# 4      CITROEN    141         2053            19           1560.0    Diesel
#
#    Metric Urban (Cold)  Metric Extra-Urban  Metric Combined  \
# 0                  4.3                 2.9              3.4
# 1                  3.9                 3.1              3.4
# 2                  3.9                 3.1              3.4
# 3                  3.7                 3.1              3.3
# 4                  3.9                 3.2              3.4
#
#    Imperial Urban (Cold)  ...  Imperial Combined  CO2 g/km  \
# 0                   65.7  ...               83.1        89
# ...

# %%
encoder.classes_
# Out:
# array([' 3.0L TDV6 (300PS) Automatic (SWB & LWB) - Dunlop 20" tyres',
#        " A 250 AMG with 18'' rear wheels", "'1 Air' 1.0 65bhp ", ...,
#        "night sky BRABUS 109hp (80kW) with 17'' rear wheels",
#        "vRS 2.0 TDI 184PS DSG 4x4 Stop-Start 18'' and 19'' wheels",
#        "vRS 2.0 TDI 184PS DSG 4x4 Stop-Start with 18'' & 19'' wheels"],
#       dtype=object)

# %%
#Use GET dummies

# %%
Car_df = pd.get_dummies(Car_df, columns=['Manufacturer','Fuel Type'])

# %%
Car_df['Total cost / 12000 miles']=Car_df['Total cost / 12000 miles'].str.replace('£','')

# %%
Car_df.head()
# Out:
#    Model  Description  Transmission  Engine Capacity  Metric Urban (Cold)  \
# 0    330          342            28           1248.0                  4.3
# 1      1          902            30           1496.0                  3.9
# 2      3          902            30           1496.0                  3.9
# 3    140         2048            28           1560.0                  3.7
# 4    141         2053            19           1560.0                  3.9
#
#    Metric Extra-Urban  Metric Combined  Imperial Urban (Cold)  \
# 0                 2.9              3.4                   65.7
# 1                 3.1              3.4                   72.4
# 2                 3.1              3.4                   72.4
# 3                 3.1              3.3                   76.3
# 4                 3.2              3.4                   72.4
#
#    Imperial Extra-Urban  Imperial Combined  ...  Manufacturer_TOYOTA  \
# 0                  97.4               83.1  ...                    0
# ...

# %%
Car_df.loc[0]

# %%
#after encoding there are diversity in values in some columns so i will use the min-max-scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Car_df[['Model']]= scaler.fit_transform(Car_df[['Model']])

# %%
scaler = MinMaxScaler()
Car_df[['Description']]= scaler.fit_transform(Car_df[['Description']])

# %%
Car_df[['Engine Capacity']]= scaler.fit_transform(Car_df[['Engine Capacity']])

# %% [markdown]
# ## Congratulations the dataset is almost ready for prediction

# %%
##First split the data to test and train samples

# %%
x_train.shape, x_test.shape

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# take a look how the values was before and after the scalling 
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
#didnot give good results,try standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# take a look how the values was before and after the scalling 
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
Car_df.fillna(Car_df.mean())
X = Car_df[['Engine Capacity','Transmission','Fuel Type_Diesel','Fuel Type_Petrol']]
X = X.apply(pd.to_numeric, errors='coerce')

Y =Car_df['Total cost / 12000 miles']



Y = Y.apply(pd.to_numeric, errors='coerce')
X = scaler.fit_transform(X)

x_train, x_test, y_train, y_test = train_test_split(X, Y)
x_train =X[:500 ,3].astype(float).reshape(-1, 1).astype(np.float64)
x_test=X[:100 ,3].astype(float).reshape(-1, 1).astype(np.float64)
y_train =Y[:500].astype(float)
y_test=Y[:100].astype(float)

# %%
x_train.shape,x_test.shape
# Out:
# ((500, 1), (100, 1))

# %%
y_train.shape,y_test.shape
# Out:
# ((500,), (100,))

# %%
Car_df[['Description']] = preprocessing.scale(Car_df[['Description']].astype('float64'))
Car_df[['Engine Capacity']] = preprocessing.scale(Car_df[['Engine Capacity']].astype('float64'))

# %%
Car_df = Car_df.dropna(axis = 1, how ='any')

# %%
Car_df.isnull().sum()
# Out:
# Model                                0
# Description                          0
# Transmission                         0
# Engine Capacity                      0
# Metric Urban (Cold)                  0
# Metric Extra-Urban                   0
# Metric Combined                      0
# Imperial Urban (Cold)                0
# Imperial Extra-Urban                 0
# Imperial Combined                    0
# CO2 g/km                             0
# Total cost / 12000 miles             0
# Euro Standard                        0
# Noise Level dB(A)                    0
# Emissions CO [mg/km]                 0
# THC Emissions [mg/km]                0
# Emissions NOx [mg/km]                0
# THC + NOx Emissions [mg/km]          0
# Particulates [No.] [mg/km]           0
# Manufacturer_ABARTH                  0
# Manufacturer_ALFA ROMEO              0
# Manufacturer_ASTON MARTIN LAGONDA    0
# Manufacturer_AUDI                    0
# Manufacturer_BENTLEY MOTORS          0
# ...

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(fit_intercept=True).fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-901-f06ad9d04404> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2
# ----> 3 linear_model = LinearRegression(fit_intercept=True).fit(x_train, y_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
print("Training_score : " , linear_model.score(x_train, y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-902-c0f6f24ec91a> in <module>
# ----> 1 print("Training_score : " , linear_model.score(x_train, y_train))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
# --> 410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#     411         if y_type == 'continuous-multioutput':
#     412             warnings.warn("The default value of multioutput (not exposed in "
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      76     """
#      77     check_consistent_length(y_true, y_pred)
# ---> 78     y_true = check_array(y_true, ensure_2d=False)
# ...

# %%
y_pred = linear_model.predict(x_test)

# %%
print("Testing_score : ", r2_score(y_test, y_pred))
# Out:
# Testing_score :  0.0
