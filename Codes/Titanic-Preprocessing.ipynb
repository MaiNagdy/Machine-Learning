# %%
# import our modules 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import os
import seaborn as sns

# %%
titanic_file_path = os.path.join(os.path.pardir,'Datasets','titanic_data.csv')

# %%
titanic_df = pd.read_csv(titanic_file_path, index_col='PassengerId')

# %%
titanic_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
Label_encoding=preprocessing.LabelEncoder()
Label_encoding=Label_encoding.fit(titanic_df['Embarked'].astype(str))

# %%
titanic_df.Embarked.fillna('C', inplace=True)

# %%
titanic_df['Embarked']=Label_encoding.transform(titanic_df['Embarked'])

# %%
titanic_df.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin  Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN         2
# 888          female  19.0      0      0      112053  30.00   B42         2
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN         2
# 890            male  26.0      0      0      111369  30.00  C148         0
# 891            male  32.0      0      0      370376   7.75   NaN         1

# %%
Label_encoding.classes_
# Out:
# array(['C', 'Q', 'S', 'nan'], dtype=object)

# %%
Label_encoding.classes_
# Out:
# array(['C', 'Q', 'S', 'nan'], dtype=object)

# %%
#Use hot encoding instead of labelencoder

titanic_df = pd.get_dummies(titanic_df, columns=['Sex'])

# %%
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
Label_encoding.classes_
# Out:
# array(['C', 'Q', 'S', 'nan'], dtype=object)

# %%
titanic_df = pd.get_dummies(titanic_df, columns=['Embarked'])

# %%
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
#Embarked 0,1,2 are C,Q,S respectivily
titanic_df['Embarked_C']=titanic_df['Embarked_0']

# %%
titanic_df =titanic_df.drop("Embarked_0", axis=1)

# %%
titanic_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
#
#              Parch            Ticket     Fare Cabin  Sex_female  Sex_male  \
# PassengerId
# 1                0         A/5 21171   7.2500   NaN           0         1
# 2                0          PC 17599  71.2833   C85           1         0
# ...

# %%
titanic_df['Embarked_Q']=titanic_df['Embarked_1']
titanic_df =titanic_df.drop("Embarked_1", axis=1)

# %%
titanic_df['Embarked_S']=titanic_df['Embarked_2']
titanic_df =titanic_df.drop("Embarked_2", axis=1)

# %%
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
titanic_df.Cabin.isnull().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
#replacing all null value of age with the mean age as most of them are young and only little between 70's
#push overall mean

titanic_df.Age.fillna(titanic_df.Age.mean(), inplace=True)

# %%
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
titanic_df['Age'].isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
#most of Cabin names are null values
#so i can replace these values with the one that accour most,as they are strings not number
df=titanic_df.groupby(['Cabin']).agg({'Cabin':'count'})

# %%
#max no of accourance is 4
df[df['Cabin']==4]
# Out:
#              Cabin
# Cabin
# B96 B98          4
# C23 C25 C27      4
# G6               4

# %%
titanic_df.fillna('G6',inplace=True) #filled with the cabin name that appeared much

# %%
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %% [markdown]
# #### Try to find the missing values in the data

# %%
titanic_df.info() #after processing no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 14 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Name          891 non-null object
# Age           891 non-null float64
# SibSp         891 non-null int64
# Parch         891 non-null int64
# Ticket        891 non-null object
# Fare          891 non-null float64
# Cabin         891 non-null object
# Sex_female    891 non-null uint8
# Sex_male      891 non-null uint8
# Embarked_C    891 non-null uint8
# Embarked_Q    891 non-null uint8
# Embarked_S    891 non-null uint8
# dtypes: float64(2), int64(4), object(3), uint8(5)
# memory usage: 74.0+ KB

# %%
titanic_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
#
#              Parch            Ticket     Fare Cabin  Sex_female  Sex_male  \
# PassengerId
# 1                0         A/5 21171   7.2500    G6           0         1
# 2                0          PC 17599  71.2833   C85           1         0
# ...

# %%
#As we see the fare and pclass are highly correlated with the survived column which will be the target
